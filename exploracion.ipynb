# %% [markdown]
# # Exploración del dataset
#     Aquí se analizará el dataset para posteriormente aplicar transfromaciones de ser necesario

# %%
import pandas as pd
import numpy as np
import logging
from config import API_BASE_URL, API_TOKEN, EMAIL
from ingest import fetch_data, parse_data
from transform import transform_categories

PARAMS = {
    "email": EMAIL,
    "key": API_TOKEN,
    "type": "ecommerce",
    "rows": 1000,
    "format": "json"
}

CATEGORIES = 'categories'
BRANDS = 'brands'
SUPPLIERS = 'suppliers'
WAREHOUSES = 'warehouses'
PRODUCTS = 'products'
INVENTORY = 'inventory'
CUSTOMERS = 'customers'
PROMOTIONS = 'promotions'
ORDERS = 'orders'
ORDER_ITEMS = 'order_items'
REVIEWS = 'reviews'

logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger(__name__)

try:
    resp = fetch_data(API_BASE_URL, PARAMS, logger)
    tables = parse_data(resp)

    print(tables.keys())
except Exception as e:
    logger.error(f"An error occurred: {e}")
# Out:
# 2026-01-10 19:55:06,545 - INFO - Fetching 1000 rows of ecommerce data...
# dict_keys(['categories', 'brands', 'suppliers', 'warehouses', 'products', 'inventory', 'customers', 'promotions', 'orders', 'order_items', 'reviews'])

# %%
tables[CATEGORIES].info()
tables[CATEGORIES].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   category_id         10 non-null     int64
#  1   category_name       10 non-null     object
#  2   description         10 non-null     object
#  3   parent_category_id  2 non-null      float64
#  4   is_active           10 non-null     bool
#  5   display_order       10 non-null     int64
# dtypes: bool(1), float64(1), int64(2), object(2)
# memory usage: 542.0+ bytes
#    category_id category_name               description  parent_category_id  \
# 0            1   Electrónica  Productos de electrónica                 NaN
# 1            2          Ropa         Productos de ropa                 1.0
# 2            3         Hogar        Productos de hogar                 NaN
# 3            4      Deportes     Productos de deportes                 1.0
# ...

# %%
tables[BRANDS].info()
tables[BRANDS].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand_id           15 non-null     int64
#  1   brand_name         15 non-null     object
#  2   country_of_origin  15 non-null     object
#  3   founded_year       15 non-null     int64
#  4   website            15 non-null     object
#  5   is_premium         15 non-null     bool
# dtypes: bool(1), int64(2), object(3)
# memory usage: 747.0+ bytes
#    brand_id  brand_name country_of_origin  founded_year  \
# 0         1     TechPro            Brasil          1989
# 1         2    StyleMax             Japón          2012
# 2         3    HomeLife             China          1952
# 3         4  SportElite            Brasil          2013
# 4         5   BookWorld            Brasil          1977
#
#                       website  is_premium
# ...

# %%
tables[SUPPLIERS].info()
tables[SUPPLIERS].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   supplier_id    8 non-null      int64
#  1   supplier_name  8 non-null      object
#  2   contact_name   8 non-null      object
#  3   email          8 non-null      object
#  4   phone          8 non-null      object
#  5   address        8 non-null      object
#  6   rating         8 non-null      float64
#  7   is_active      8 non-null      bool
# dtypes: bool(1), float64(1), int64(1), object(5)
# memory usage: 588.0+ bytes
#    supplier_id        supplier_name  contact_name  \
# 0            1  Distribuidora Norte  Carlos López
# 1            2      Importadora Sur    Juan Pérez
# 2            3    Mayorista Central  María García
# 3            4    Logística Express    Juan Pérez
# 4            5   Proveedores Unidos    Juan Pérez
#
# ...

# %%
tables[WAREHOUSES].info()
tables[WAREHOUSES].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   warehouse_id       5 non-null      int64
#  1   warehouse_name     5 non-null      object
#  2   location           5 non-null      object
#  3   capacity_units     5 non-null      int64
#  4   current_occupancy  5 non-null      int64
#  5   manager_name       5 non-null      object
# dtypes: int64(3), object(3)
# memory usage: 372.0+ bytes
#    warehouse_id warehouse_name      location  capacity_units  \
# 0             1     Depósito 1  Buenos Aires           14590
# 1             2     Depósito 2       Córdoba           24414
# 2             3     Depósito 3       Rosario           17573
# 3             4     Depósito 4       Mendoza           40839
# 4             5     Depósito 5      La Plata           85334
#
#    current_occupancy     manager_name
# ...

# %%
tables[PRODUCTS].info()
tables[PRODUCTS].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    100 non-null    int64
#  1   sku           100 non-null    object
#  2   product_name  100 non-null    object
#  3   description   100 non-null    object
#  4   category_id   100 non-null    int64
#  5   brand_id      100 non-null    int64
#  6   supplier_id   100 non-null    int64
#  7   price         100 non-null    float64
#  8   cost          100 non-null    float64
#  9   weight_kg     100 non-null    float64
#  10  is_active     100 non-null    bool
#  11  created_at    100 non-null    object
#  12  updated_at    100 non-null    object
# dtypes: bool(1), float64(3), int64(4), object(5)
# memory usage: 9.6+ KB
#    product_id         sku       product_name  \
# 0           1  SKU-000001       Pro Widget 1
# 1           2  SKU-000002     Pro Producto 2
# ...

# %%
tables[INVENTORY].info()
tables[INVENTORY].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   inventory_id       195 non-null    int64
#  1   product_id         195 non-null    int64
#  2   warehouse_id       195 non-null    int64
#  3   quantity           195 non-null    int64
#  4   min_stock_level    195 non-null    int64
#  5   max_stock_level    195 non-null    int64
#  6   last_restock_date  195 non-null    object
# dtypes: int64(6), object(1)
# memory usage: 10.8+ KB
#    inventory_id  product_id  warehouse_id  quantity  min_stock_level  \
# 0             1           1             2        71               46
# 1             2           2             5       161               48
# 2             3           3             3       263               13
# 3             4           3             1       222               12
# ...

# %%
tables[CUSTOMERS].info()
tables[CUSTOMERS].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 0 to 333
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        334 non-null    int64
#  1   first_name         334 non-null    object
#  2   last_name          334 non-null    object
#  3   email              334 non-null    object
#  4   phone              334 non-null    object
#  5   birth_date         334 non-null    object
#  6   city               334 non-null    object
#  7   country            334 non-null    object
#  8   postal_code        334 non-null    int64
#  9   segment            334 non-null    object
#  10  registration_date  334 non-null    object
#  11  last_login         334 non-null    object
#  12  is_verified        334 non-null    bool
#  13  accepts_marketing  334 non-null    int64
# dtypes: bool(1), int64(3), object(10)
# memory usage: 34.4+ KB
# ...

# %%
tables[PROMOTIONS].info()
tables[PROMOTIONS].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   promotion_id      10 non-null     int64
#  1   promotion_code    10 non-null     object
#  2   promotion_name    10 non-null     object
#  3   promotion_type    10 non-null     object
#  4   discount_value    10 non-null     int64
#  5   min_order_amount  10 non-null     int64
#  6   max_uses          10 non-null     int64
#  7   current_uses      10 non-null     int64
#  8   start_date        10 non-null     object
#  9   end_date          10 non-null     object
#  10  is_active         10 non-null     bool
# dtypes: bool(1), int64(5), object(5)
# memory usage: 942.0+ bytes
#    promotion_id promotion_code promotion_name promotion_type  discount_value  \
# 0             1    PROMO9E051F    Promoción 1  free_shipping              47
# ...

# %%
tables[ORDERS].info()
tables[ORDERS].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1000 non-null   int64
#  1   order_number      1000 non-null   object
#  2   customer_id       1000 non-null   int64
#  3   order_date        1000 non-null   object
#  4   status            1000 non-null   object
#  5   subtotal          1000 non-null   float64
#  6   discount_percent  1000 non-null   int64
#  7   shipping_cost     1000 non-null   int64
#  8   tax_amount        1000 non-null   float64
#  9   total_amount      1000 non-null   float64
#  10  payment_method    1000 non-null   object
#  11  shipping_method   1000 non-null   object
#  12  promotion_id      252 non-null    float64
#  13  notes             158 non-null    object
# dtypes: float64(4), int64(4), object(6)
# memory usage: 109.5+ KB
# ...

# %%
tables[ORDER_ITEMS].info()
tables[ORDER_ITEMS].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3031 entries, 0 to 3030
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_item_id  3031 non-null   int64
#  1   order_id       3031 non-null   int64
#  2   product_id     3031 non-null   int64
#  3   quantity       3031 non-null   int64
#  4   unit_price     3031 non-null   float64
#  5   subtotal       3031 non-null   float64
# dtypes: float64(2), int64(4)
# memory usage: 142.2 KB
#    order_item_id  order_id  product_id  quantity  unit_price  subtotal
# 0              1         1          73         3      495.49   1486.47
# 1              2         1          66         1      420.57    420.57
# 2              3         1          42         5      470.54   2352.70
# 3              4         1          15         5      388.21   1941.05
# 4              5         1          73         4      495.49   1981.96

# %%
tables[REVIEWS].info()
tables[REVIEWS].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   review_id             200 non-null    int64
#  1   product_id            200 non-null    int64
#  2   customer_id           200 non-null    int64
#  3   rating                200 non-null    int64
#  4   title                 200 non-null    object
#  5   comment               200 non-null    object
#  6   is_verified_purchase  200 non-null    bool
#  7   helpful_votes         200 non-null    int64
#  8   created_at            200 non-null    object
# dtypes: bool(1), int64(5), object(3)
# memory usage: 12.8+ KB
#    review_id  product_id  customer_id  rating               title  \
# 0          1          63           12       4      Podría mejorar
# 1          2          71           29       3  Excelente producto
# ...
